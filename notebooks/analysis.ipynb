# %% [markdown]
# # Analysis and Results
#
# This notebook loads `reports/metrics_summary.csv`, shows tables and the generated plots.

# %%
import pandas as pd
from IPython.display import Image, display

metrics = pd.read_csv('../reports/metrics_summary.csv')
metrics

# %%
for label in metrics['label']:
    display(Image(f'../reports/figs/{label}_roc.png'))
    display(Image(f'../reports/figs/{label}_pr.png'))
    display(Image(f'../reports/figs/{label}_cm.png'))
